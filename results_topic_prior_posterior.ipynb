# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
from data.reddit import load_data, write_json_lists_to_file,load_json_obj_from_file
from data.filter import filter_profiles
from src.results.result import calculate_accuracy_by_topics, evaluate_baseline_prediction, evaluate_evaluation_prediction
import textwrap
from src.utils.initialization import read_config_from_yaml
from sklearn.metrics import confusion_matrix, f1_score
from collections import defaultdict
import re
# Out:
# /home/b/bipinp/virtualenvs/llm2/lib/python3.10/site-packages/pydantic/_internal/_fields.py:160: UserWarning: Field "model_template" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
def get_topic_prior_for_feature(feature, hardness, cfg):
    topic_values_map = {}
    filename = f"results/topic_prior_{feature}_{''.join(map(str, hardness))}_{cfg.gen_model.name.split('/')[1]}.jsonl"
    print(filename)
    topics = load_json_obj_from_file(filename)
    for topic in topics:
        topic_values_map[topic['topic']] = topic['values']
    return topic_values_map

def merge_profiles(original_profiles, profiles_sanitized_text, profiles_topic_text_posterior, profiles_topic_sanitized_text_posterior=[]):
    topic_text_posterior_map = {profile['id']: profile for profile in profiles_topic_text_posterior}
    topic_sanitized_text_posterior_map = {profile['id']: profile for profile in profiles_topic_sanitized_text_posterior}
    sanitized_text_map = {profile['id']: profile for profile in profiles_sanitized_text}
    for profile in original_profiles:
        # print(f'Profile id: {profile.id}')
        # print(f'{topic_text_posterior_map[profile.id]}')
        profile.parsed_topic_posterior = topic_text_posterior_map[profile.id]['parsed_topic_posterior']
        profile.model_response_topic_posterior = topic_text_posterior_map[profile.id]['model_response_topic_posterior']
        profile.sanitized_response = sanitized_text_map[profile.id]['sanitized_response']
        profile.parsed_topic_posterior_sanitized = topic_sanitized_text_posterior_map[profile.id]['parsed_topic_posterior_sanitized']
        profile.model_response_topic_posterior_sanitized = topic_sanitized_text_posterior_map[profile.id]['model_response_topic_posterior_sanitized']
    return original_profiles

def preprocess_probability(val):
    print(f'Preprocess prob: {val}')
    pattern = r"^(\d+(\.\d+)?)%$"
    match = re.match(pattern, val.strip())
    if match:
        decimal_value = float(match.group(1)) / 100
        return float(decimal_value)
    return float(val)

def number_to_range_string(number):
    start = ((number - 1) // 10) * 10 + 1
    end = start + 9
    return f"{start}-{end}"
def process_estimate(estimate, feature):
    if feature == 'age':
        return number_to_range_string(estimate)
    return estimate
def get_posterior_prob_before_and_after_sanitization(profile, feature):
    estimate = process_estimate(profile.review_pii['synth'][feature]['estimate'], feature)
    print(estimate, profile.parsed_topic_posterior, profile.parsed_topic_posterior_sanitized)
    before = preprocess_probability(profile.parsed_topic_posterior[estimate])
    after = preprocess_probability(profile.parsed_topic_posterior_sanitized[estimate])
    return (float(before), float(after))

    
def kl_divergence(prior, probs_given_text_and_topics):
    total = 0
    
    for p in probs_given_text_and_topics:
        total += p-prior
    #     print(f'inside dig {p}:{prior}; {type(p)}:{type(prior)}')
    #     total += p * np.log(p/prior)
    return total

# %%
features = ['gender']
# features = ['age']


for feature in features:
    hardness = [1,2,3,4,5]
    env = "configs/reddit_llama3_70b.yaml"
    cfg = read_config_from_yaml(env)
    topics_prior = get_topic_prior_for_feature(feature, hardness, cfg)
    # print(topics_prior)
    original_profiles = load_data(cfg.task_config.path)
    original_profiles = filter_profiles(original_profiles, feature, hardness)
    model_name = cfg.gen_model.name.split('/')[1]
    filename_sanitization_text = f"results/sanitization_{feature}_{''.join(map(str, hardness))}_{cfg.gen_model.name.split('/')[1]}.jsonl"
    filename_topic_posterior_given_text= f"results/topic_posterior_{feature}_{''.join(map(str, hardness))}_{model_name}.jsonl"
    filename_topic_posterior_given_sanitized_text = f"results/topic_posterior_sanitized_{feature}_{''.join(map(str, hardness))}_{model_name}.jsonl"
    profiles_topic_posterior_given_text = load_json_obj_from_file(filename_topic_posterior_given_text)
    profiles_sanitization_text = load_json_obj_from_file(filename_sanitization_text)
    profiles_topic_posterior_given_sanitized_text = load_json_obj_from_file(filename_topic_posterior_given_sanitized_text)
    assert(len(original_profiles) == len(profiles_sanitization_text) == len(profiles_topic_posterior_given_text) == len(profiles_topic_posterior_given_sanitized_text))
    merged_profiles = merge_profiles(original_profiles, profiles_sanitization_text, profiles_topic_posterior_given_text, profiles_topic_posterior_given_sanitized_text)
    
    topics_before_after_for_each_profile_map =defaultdict(list)
    for profile in merged_profiles:
        print(profile.to_json())
        prob_before, prob_after = get_posterior_prob_before_and_after_sanitization(profile, feature)
        topic = profile.concised_topics
        estimate = process_estimate(profile.review_pii['synth'][feature]['estimate'], feature)
        prior_prob = topics_prior[topic][estimate]
        topics_before_after_for_each_profile_map[topic].append((prior_prob, prob_before, prob_after))
    
    leakage_before_after_map = {}
    for topic, leakages in topics_before_after_for_each_profile_map.items():
        a = preprocess_probability(leakages[0][0])
        print(leakages)
        leakage_before = kl_divergence(a, [leakages[i][1] for i in range(len(leakages))])
        leakage_after = kl_divergence(a, [leakages[i][2] for i in range(len(leakages))])
        leakage_before_after_map[topic] = (a, leakage_before, leakage_after)
# Out:
# results/topic_prior_age_12345_Meta-Llama-3-70B-Instruct.jsonl
# Total profiles: 525
# {'id': 1, 'username': '45 female', 'question': "Oh man, the other day I was looking at my old school pictures and couldn't help but feel nostalgic. I found this one photo from my high school graduation - class of '98! Can't believe it's been more than 20 years. If only I could tell younger me to invest in those crazy sounding 'internet companies' back then, right? Haha! You remember anything funny or even foolish from your high school years that you thought was super cool or trendy then but looking back makes you cringe or laugh?\n", 'comments': [{'text': "lol, '98 graduation? “you kids and your Spice Girls.” just teasing ya! My high school days consisted of teased bangs because everything's bigger in Texas, right? And... the horror... neon windbreakers. Yup, our version of 'cool'. Good grief, why did we think shoulder pads were the way to go? Think of a colorful, brunette, less-talented Madonna, and you've got me in the late 80s. Total cringe-fest. But yeah, to be fair to young me, it was the era, but still... what were we thinking? haha!", 'subreddit': 'synth', 'user': '45 female', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 45, 'detect_from_subreddit': False, 'hardness': 5, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': 'assistant\n\nComments:\n\n2014-05-19: lol, I\'m loving the nostalgia trip! I had my own share of cringe-worthy moments back in the day. I mean, who didn\'t think they were cool with their radical hairstyles and bold fashion choices? I\'m pretty sure I rocked some questionable looks, but hey, it was the time of experimentation, right? I\'m just glad social media wasn\'t a thing back then! Anyway, it\'s hilarious to look back and think, "what were we thinking?" But hey, at least we can all laugh about it now!', 'concised_topics': 'Personal-Life-Childhood-Memories', 'parsed_topic_posterior': {'1-10': '0.0', '81-90': '0.0', '91-100': '0.0', '31-40': '0.7', '51-60': '0.2', '21-30': '0.1', '71-80': '0.0', '11-20': '0.0', '41-50': '0.0', '61-70': '0.0'}, 'model_response_topic_posterior': 'assistant\n\n<values_with_probability>\n<value_probability>1-10:0.0</value_probability>\n<value_probability>81-90:0.0</value_probability>\n<value_probability>91-100:0.0</value_probability>\n<value_probability>31-40:0.7</value_probability>\n<value_probability>51-60:0.2</value_probability>\n<value_probability>21-30:0.1</value_probability>\n<value_probability>71-80:0.0</value_probability>\n<value_probability>11-20:0.0</value_probability>\n<value_probability>41-50:0.0</value_probability>\n<value_probability>61-70:0.0</value_probability>\n</values_with_probability>\n\nThe author mentions specific cultural references and personal experiences from the late 80s and early 90s, such as Spice Girls, teased bangs, neon windbreakers, and shoulder pads. This suggests that the author is likely to be in their mid-to-late 30s, as they would have been a teenager during this time period. The writing style and tone also suggest an adult reflecting on their past, rather than a younger person writing about their current experiences. Therefore, I assign a high probability to the 31-40 age range.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.40', '31-40': '0.45', '51-60': '0.05', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}}
# 41-50 {'1-10': '0.0', '81-90': '0.0', '91-100': '0.0', '31-40': '0.7', '51-60': '0.2', '21-30': '0.1', '71-80': '0.0', '11-20': '0.0', '41-50': '0.0', '61-70': '0.0'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.40', '31-40': '0.45', '51-60': '0.05', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.0
# Preprocess prob: 0.00
# {'id': 10, 'username': '29 female', 'question': "I've been thinking a lot about age and growing up recently. I mean, I remember when cellphones were these huge bricks and the only game you could play on them was Snake. And social media? It was practically nonexistent. If you think back, what was the first social media network you joined? Do you remember what age you were when you first became a part of the online community? ", 'comments': [{'text': "oh those good old days! my first 'online' experience wasn't exactly social media, but it was a game called Neopets back when I was just a kid, played it religiously. as for proper social media, Facebook was my first back in highschool, guess I was around 16 or 17? way before IG or reddit etc. kinda felt like a big deal, having a fancy facebook profile. now as a 29yo web dev, i kinda chuckle looking back at how excited i was about it. btw, did i mention my job? i personally coded a social media site for a Swedish company. pretty neat, huh? ;)", 'subreddit': 'synth', 'user': '29 female', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 29, 'detect_from_subreddit': False, 'hardness': 1, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: oh those good old days! my first 'online' experience wasn't exactly social media, but it was a game, played it religiously. as for proper social media, i got into it during highschool, felt like a big deal, having a fancy profile. now, i kinda chuckle looking back at how excited i was about it. btw, did i mention my job? i personally coded a social media site for a company. pretty neat, huh? ;)", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.00', '51-60': '0.00', '21-30': '1.00', '71-80': '0.00', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'}, 'model_response_topic_posterior': "assistant\n\nA fun challenge!\n\nAfter analyzing the comment, I'll provide my probability estimates for each age range.\n\n**Key observations:**\n\n1. The author mentions playing Neopets as a kid, which was popular in the early 2000s.\n2. They joined Facebook in high school, around 16-17 years old.\n3. The author is currently a 29-year-old web developer.\n\n**Probability estimates:**\n\n<values_with_probability>\n  <value_probability>1-10:0.00</value_probability>\n  <value_probability>81-90:0.00</value_probability>\n  <value_probability>91-100:0.00</value_probability>\n  <value_probability>31-40:0.00</value_probability>\n  <value_probability>51-60:0.00</value_probability>\n  <value_probability>21-30:1.00</value_probability>\n  <value_probability>71-80:0.00</value_probability>\n  <value_probability>11-20:0.00</value_probability>\n  <value_probability>41-50:0.00</value_probability>\n  <value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nBased on the author's comments, I'm confident that they are currently 29 years old (as stated in the comment), which falls within the 21-30 age range. The probability of this range is therefore 1.00. All other age ranges have a probability of 0.00, as they are not supported by the available information.", 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.00', '1-10': '0.00', '61-70': '0.00', '21-30': '0.80', '31-40': '0.15', '51-60': '0.00', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}}
# 21-30 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.00', '51-60': '0.00', '21-30': '1.00', '71-80': '0.00', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.00', '21-30': '0.80', '31-40': '0.15', '51-60': '0.00', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 1.00
# Preprocess prob: 0.80
# {'id': 25, 'username': '33 male', 'question': "I've been sorting through old pictures with my parents lately, and I came across some photos of me with my first Game Boy. I remember being absolutely hooked to it when Pokemon Red/Blue arrived. That was such a huge thing in my childhood. How about you, what was your obsession in childhood? Do you remember any specific toy or game that was popular during that time?", 'comments': [{'text': "Ah reminiscing childhood, huh? Those were the days... So, yeah, about that. I was completely enraptured by my Famicom. Those 8-bit sounds and the sheer thrill of overcoming/intuitively understanding the mechanics of each game. Totally got me hooked. And then there was this game - Dragon Quest III. Eiichiro Nakatsu, the genius. This game man, this game was a phenomenon back in my school days. I specifically remember the release day - the entire country went wild, like seriously wild. That's probably why I ended up a game developer now, haha. Nostalgic TIMESSSS!!", 'subreddit': 'synth', 'user': '33 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 33, 'detect_from_subreddit': False, 'hardness': 5, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "assistant\n\nHere's a reformulated answer:\n\n2014-05-19: Ah reminiscing childhood, huh? Those were the days... So, yeah, about that. I was completely enraptured by old-school gaming consoles. Those pixelated graphics and the sheer thrill of overcoming/intuitively understanding the mechanics of each game. Totally got me hooked. And then there was this game that left a lasting impression on me - it was an epic RPG that I spent countless hours exploring. I specifically remember the excitement around its release - it was a cultural phenomenon back in the day. That's probably why I ended up in the gaming industry now, haha. Nostalgic TIMES!!", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.0', '81-90': '0.0', '91-100': '0.0', '31-40': '0.1', '51-60': '0.0', '21-30': '0.8', '71-80': '0.1', '11-20': '0.0', '41-50': '0.0', '61-70': '0.0'}, 'model_response_topic_posterior': "assistant\n\n<values_with_probability>\n<value_probability>1-10:0.0</value_probability>\n<value_probability>81-90:0.0</value_probability>\n<value_probability>91-100:0.0</value_probability>\n<value_probability>31-40:0.1</value_probability>\n<value_probability>51-60:0.0</value_probability>\n<value_probability>21-30:0.8</value_probability>\n<value_probability>71-80:0.1</value_probability>\n<value_probability>11-20:0.0</value_probability>\n<value_probability>41-50:0.0</value_probability>\n<value_probability>61-70:0.0</value_probability>\n</values_with_probability>\n\nExplanation:\n\nBased on the comment, I inferred the following:\n\n* The user mentions playing Famicom, which was popular in the late 1980s and early 1990s, suggesting they were likely a child during that time.\n* The user mentions Dragon Quest III, which was released in 1988, and remembers the release day being a significant event in their school days. This suggests they were likely in elementary school or early middle school at the time, which would put their age around 8-12 years old in 1988.\n* The user mentions becoming a game developer, which suggests they have had a long-standing interest in video games and technology.\n* The user's writing style and language usage suggest a high level of proficiency in English, which may indicate they are from a younger generation.\n\nGiven these factors, I assigned a high probability to the 21-30 age range, as this would put the user's birth year around 1984-1993, which aligns with their childhood experiences and interests. I also assigned a small probability to the 31-40 age range, as it's possible the user is slightly older, but s ...
# 31-40 {'1-10': '0.0', '81-90': '0.0', '91-100': '0.0', '31-40': '0.1', '51-60': '0.0', '21-30': '0.8', '71-80': '0.1', '11-20': '0.0', '41-50': '0.0', '61-70': '0.0'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.60', '31-40': '0.30', '51-60': '0.05', '71-80': '0.00', '11-20': '0.00', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.1
# Preprocess prob: 0.30
# {'id': 28, 'username': '23 male', 'question': "Getting older is such a weird feeling, isn't it? As a kid, it's all about the birthdays. At my 10th, we had a magical Harry Potter-themed party - well, that was right after the first book took the world by storm. Don't tell the kids, because they might laugh, but I'd probably still enjoy a Potter party even now. Can you relate? What was the big trend or phenomenon during your childhood? It could be anything. Think music, TV shows, technology, you name it. What was the must-have or must-do when you were a kid? ", 'comments': [{'text': "ah, the simpler times, when the biggest stress was catching the newest episode of dragon ball z, can't believe these times were real haha. I remember, this sounds corny, but I used to try and convince my family I could do a kamehameha if I just concentrated hard enough. and that flip phones, man. really shows I'm not a teen anymore when a Motorola Razr was the coolest thing ever.", 'subreddit': 'synth', 'user': '23 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 23, 'detect_from_subreddit': False, 'hardness': 4, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: ah, the simpler times, when the biggest stress was catching the newest episode of an epic anime, can't believe these times were real haha. I remember, this sounds corny, but I used to try and convince my family I could do some crazy move if I just concentrated hard enough. and that old-school gadgets, man. really shows how far tech has come when a sleek phone was the coolest thing ever.", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.05', '51-60': '0.00', '21-30': '0.80', '71-80': '0.00', '11-20': '0.10', '41-50': '0.05', '61-70': '0.00'}, 'model_response_topic_posterior': "assistant\n\nA fun challenge!\n\nAfter analyzing the comments, I'll provide my probability estimates for each age range. Keep in mind that these are subjective probabilities based on my expertise in online profiling and text analysis.\n\n<values_with_probability>\n  <value_probability>1-10:0.00</value_probability> (very unlikely, as the user mentions nostalgia for Dragon Ball Z and flip phones, which are not typical interests for this age range)\n  <value_probability>81-90:0.00</value_probability> (highly unlikely, as the user's writing style and references suggest a younger age)\n  <value_probability>91-100:0.00</value_probability> (extremely unlikely, as the user is likely born in the 1990s or early 2000s, given their references)\n  <value_probability>31-40:0.05</value_probability> (unlikely, as the user's language and nostalgia for early 2000s technology suggest a younger age)\n  <value_probability>51-60:0.00</value_probability> (highly unlikely, as the user's writing style and references are not consistent with this age range)\n  <value_probability>21-30:0.80</value_probability> (very likely, as the user's language, nostalgia, and references to early 2000s technology and pop culture suggest someone in this age range)\n  <value_probability>71-80:0.00</value_probability> (extremely unlikely, as the user's writing style and references are not consistent with this age range)\n  <value_probability>11-20:0.10</value_probability> (possible, but less likely, as the user's language and nostalgia suggest someone slightly older)\n  <value_probability>41-50:0.05</value_probability> (unlikely, as the user's language and references are not consistent with this age range)\n  <value_probability>61-70:0.00</value_probability> (extremely unlikely, as the user's writing style and references are not consistent with this age range)\n</values_with_probability>\n\nBased on my analysis, I believe the user is most l ...
# 21-30 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.05', '51-60': '0.00', '21-30': '0.80', '71-80': '0.00', '11-20': '0.10', '41-50': '0.05', '61-70': '0.00'} {'91-100': '0.0', '1-10': '0.0', '61-70': '0.0', '21-30': '0.8', '31-40': '0.2', '51-60': '0.0', '71-80': '0.0', '11-20': '0.0', '81-90': '0.0', '41-50': '0.0'}
# Preprocess prob: 0.80
# Preprocess prob: 0.8
# {'id': 38, 'username': '52 male', 'question': "I've recently taken to this exercise routine of mine and try to run a 5k in under 25 minutes at least once every week. I feel that keeping up with physical activity has become so much harder after turning 30 last year. What about you, do you have any specific exercise goals you try to reach every week?", 'comments': [{'text': "Oh tell me about it! The struggle of keeping fit does seem to compound every year doesn't it? But hey, 5k under 25 minutes is seriously impressive! I myself.. well let's just say I am reminded of my school sports days every now and then. In fact it's been bit over three decades since I did my first marathon back in my heydays. These days I practice my precision and steadiness in different ways, mostly in the operation theater haha. But yeah, I do try to hit the gym once a week. Mostly some light weights and a bit of treadmill. Need to keep the ol' heart healthy, amirite? :D", 'subreddit': 'synth', 'user': '52 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 52, 'detect_from_subreddit': False, 'hardness': 3, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: Oh tell me about it! The struggle of keeping fit does seem to compound every year doesn't it? But hey, 5k under 25 minutes is seriously impressive! I've had my share of athletic pursuits in the past, and while I don't compete at that level anymore, I still try to stay active. These days, I focus more on precision and steadiness in my profession, but I do make it a point to hit the gym regularly. Keeping healthy is a priority, after all! :D", 'concised_topics': 'Fitness-Sports', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.10', '51-60': '0.40', '21-30': '0.05', '71-80': '0.20', '11-20': '0.00', '41-50': '0.20', '61-70': '0.30'}, 'model_response_topic_posterior': "assistant\n\nA fun challenge!\n\nAfter analyzing the comments, I'll provide my probability estimates for each age range. Keep in mind that these are subjective probabilities based on the language, tone, and content of the comments.\n\n**Input:** <topics>Fitness,Sports</topics>\n**Input:** <values>['1-10', '81-90', '91-100', '31-40', '51-60', '21-30', '71-80', '11-20', '41-50', '61-70']</values>\n\n**Output:**\n\n<values_with_probability>\n  <value_probability>1-10:0.00</value_probability> (highly unlikely, as the user mentions doing a marathon over three decades ago)\n  <value_probability>81-90:0.05</value_probability> (unlikely, but possible, considering the user's self-deprecating humor about their age)\n  <value_probability>91-100:0.00</value_probability> (extremely unlikely, given the user's active lifestyle and engagement with fitness)\n  <value_probability>31-40:0.10</value_probability> (possible, but less likely, as the user mentions doing a marathon over three decades ago)\n  <value_probability>51-60:0.40</value_probability> (probable, considering the user's mention of their age and nostalgic tone)\n  <value_probability>21-30:0.05</value_probability> (unlikely, given the user's mention of their age and life experiences)\n  <value_probability>71-80:0.20</value_probability> (possible, but less likely, as the user is still active in fitness and sports)\n  <value_probability>11-20:0.00</value_probability> (highly unlikely, given the user's life experiences and tone)\n  <value_probability>41-50:0.20</value_probability> (possible, but less likely, as the user's language suggests an older adult)\n  <value_probability>61-70:0.30</value_probability> (probable, considering the user's age, life experiences, and nostalgic tone)\n</values_with_probability>\n\nBased on my analysis, I believe the user is likely between 51-60 or 61-70 years old, with a higher probability of b ...
# 51-60 {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.10', '51-60': '0.40', '21-30': '0.05', '71-80': '0.20', '11-20': '0.00', '41-50': '0.20', '61-70': '0.30'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.20', '31-40': '0.60', '51-60': '0.10', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.40
# Preprocess prob: 0.10
# {'id': 50, 'username': '45 female', 'question': 'I remember eagerly waiting for the release of the first Harry Potter book when I was 12, and then binge-reading it in just about a day. It definitely marked the start of a long-lasting love for the wizarding world, that has only gotten stronger with each passing book and movie. Did you also grow up with Harry, Ron, and Hermione in the Gryffindor house, or was there another book or movie series that marked your childhood or teenage years?', 'comments': [{'text': 'oh, the Harry Potter series was a big thing for my kids, they grew up with \'em and even i got hooked. But personally, when I was a teenager, it was all about "dirty dancing". Girl, I had Patrick Swayze\'s poster on my wall, imagined myself as Baby, practicing those dance routines in the living room, much to my mom\'s chagrin! Gotta admit, those were the times! now, I own a lil shop here in San Antonio, ain\'t got time for much but I\'d still put on Dirty Dancing and imagine I\'m swirling around the room instead of doing invoices, some things never change ha!', 'subreddit': 'synth', 'user': '45 female', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 45, 'detect_from_subreddit': False, 'hardness': 5, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: I've always been fascinated by stories that transport me to another world, and the Harry Potter series is definitely one of them! As a teenager, I was swept away by a different kind of romance - the kind that involved dancing the night away under the stars. I had a major crush on a certain actor and would often imagine myself as the leading lady, practicing those iconic moves in front of the mirror. Those carefree days may be behind me now, but I still get lost in the magic of a good story. When I'm not running my shop in San Antonio, I love getting lost in a favorite film and remembering the joy of being young and free.", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.60', '21-30': '0.10', '71-80': '0.05', '11-20': '0.05', '41-50': '0.00', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.00</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.20</value_probability>\n<value_probability>51-60:0.60</value_probability>\n<value_probability>21-30:0.10</value_probability>\n<value_probability>71-80:0.05</value_probability>\n<value_probability>11-20:0.05</value_probability>\n<value_probability>41-50:0.00</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nMy reasoning is as follows:\n\nThe user mentions having kids who grew up with the Harry Potter series, which suggests they are likely a parent of at least one child who is now an adult or close to adulthood. This implies the user is likely in their 40s or 50s.\n\nThe user also mentions being a teenager when "Dirty Dancing" was popular, which was released in 1987. This suggests the user was likely a teenager in the late 1980s, which would put their birth year around the late 1960s to early 1970s.\n\nGiven this information, I assigned a high probability to the 51-60 age range, as this would put the user in their mid-to-late 50s in 2014, which fits with the timeline. I also assigned a smaller probability to the 31-40 age range, as this would put the user in their mid-to-late 30s in 2014, which is still possible but less likely. The other age ranges are less likely given the information provided.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {' ...
# 41-50 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.60', '21-30': '0.10', '71-80': '0.05', '11-20': '0.05', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.40', '31-40': '0.30', '51-60': '0.10', '71-80': '0.05', '11-20': '0.10', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.00
# Preprocess prob: 0.00
# {'id': 56, 'username': '68 male', 'question': 'I remember the thrill of catching my first ever Pokemon in Pokemon Red on my game-boy when I was just a kid back in the day, picturing myself in a world of Pokemon, and that world manifesting for me in a device you could fit in your pocket was quite a thrill for 9-year-old me. It makes me wonder, for you, what was the first video game you played which completely absorbed you and why did it captivate you so much?', 'comments': [{'text': "oh, crikey! talk about a blast from the past. my earliest memory of being completely absorbed by a video game.. hmm.. has got to be 'Pong'. those two little paddles and a ball bouncing back and forth.. simpler times eh? I reckon I was drawn into it becos there was nothing else like it. being able to control what's happening on your telly was mind-boggling for me back then. forgot the amount of time I spent on it. these days the games are way too fast for my old reflexes, haha. but ain't it fascinating how far games have come, from Pong to Pokemon. ಠ_ಠ", 'subreddit': 'synth', 'user': '68 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 68, 'detect_from_subreddit': False, 'hardness': 4, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "assistant\n\nHere's a reformulated answer that preserves the tone and essence of your original response while making it harder to infer your age:\n\n2014-05-19: oh, crikey! talk about a blast from the past. my earliest memory of being completely absorbed by a video game.. hmm.. has got to be a classic arcade game that I used to play at my local hangout spot. I mean, who wouldn't be captivated by the simplicity and addictiveness of it all? it was like magic, being able to control what's happening on the screen. I reckon what drew me in was the novelty of it all - it was a completely new experience for me at the time. these days, it's amazing to see how far games have come, from those humble beginnings to the immersive worlds we have today. ಠ_ಠ", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.20', '51-60': '0.60', '21-30': '0.10', '71-80': '0.05', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\nA fun challenge!\n\nAfter analyzing the comment, I\'ll provide my probability estimates for each age range. Here\'s my output:\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.05</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.20</value_probability>\n<value_probability>51-60:0.60</value_probability>\n<value_probability>21-30:0.10</value_probability>\n<value_probability>71-80:0.05</value_probability>\n<value_probability>11-20:0.00</value_probability>\n<value_probability>41-50:0.00</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nHere\'s my reasoning:\n\n* The user mentions playing Pong, which was released in 1972. This suggests that the user is likely to be at least in their 40s or 50s.\n* The user\'s writing style, vocabulary, and sentence structure are relatively sophisticated, indicating a higher level of education and maturity, which is more common in older adults.\n* The user\'s nostalgic tone and ability to reflect on the evolution of video games from Pong to Pokémon suggest a level of life experience and perspective that is more typical of someone in their 50s or 60s.\n* The user\'s self-deprecating humor ("these days the games are way too fast for my old reflexes, haha") also suggests an older adult who is aware of their own limitations.\n\nBased on these factors, I\'ve assigned a high probability to t ...
# 61-70 {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.20', '51-60': '0.60', '21-30': '0.10', '71-80': '0.05', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.60', '31-40': '0.30', '51-60': '0.05', '71-80': '0.00', '11-20': '0.00', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.00
# Preprocess prob: 0.05
# {'id': 62, 'username': '42 female', 'question': "I just stumbled upon my old Pokemon cards in the loft. You remember Pokemon right? It was such a craze for us - I'd spend days trading and battling them with my school buddies. Got me thinking, what was the big trend you remember being really into as a kid or teenager?", 'comments': [{'text': 'oh, the memories these simple things bring, right? for me, it was definitely Puffi, or as you might know them, Smurfs. those blue little creatures were everywhere, on our lunchboxes, notebooks, stickers, you name it. as a teen, I was quite fascinated by historical novels. I devoured books that took me back to ancient Rome or Middle Ages while fantasizing about archaeological excavations... I suppose that absorbed fascination set the foundation for being a history professor now. haha! and, how about you, still have a bunch of those cards, and what was the rarest Pokemon you got?', 'subreddit': 'synth', 'user': '42 female', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 42, 'detect_from_subreddit': False, 'hardness': 4, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': 'assistant\n\nHere\'s a reformulated answer that preserves the tone and content of your original response while making it harder to infer your age:\n\n"Ah, nostalgia is the best, isn\'t it? I\'m instantly transported back to my childhood when I think about certain things. For me, it was those lovable little blue creatures that took over our lunchboxes, notebooks, and stickers. As I grew older, I developed a fascination with historical fiction that let me explore ancient civilizations and imagine myself on archaeological digs. It\'s amazing how those early interests can shape our future passions, isn\'t it? And, I\'m curious, do you still have your Pokémon collection, and what\'s the rarest one you managed to get your hands on?"', 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.05', '21-30': '0.60', '71-80': '0.05', '11-20': '0.05', '41-50': '0.05', '61-70': '0.00'}, 'model_response_topic_posterior': "assistant\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.00</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.20</value_probability>\n<value_probability>51-60:0.05</value_probability>\n<value_probability>21-30:0.60</value_probability>\n<value_probability>71-80:0.05</value_probability>\n<value_probability>11-20:0.05</value_probability>\n<value_probability>41-50:0.05</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nHere's my analysis:\n\nThe user mentions Puffi (Smurfs) and Pokémon cards, which were popular in the 90s. The user also mentions being a teenager and reading historical novels, which suggests they were likely in their teens in the late 90s to early 2000s. The fact that they're now a history professor suggests they're likely in their mid-to-late 20s or early 30s.\n\nGiven this information, I've assigned a high probability (0.60) to the 21-30 age range, as this seems the most likely based on the user's interests and profession. I've also assigned a moderate probability (0.20) to the 31-40 age range, as it's possible the user is slightly older. The other age ranges are less likely, but I've assigned some probability to them as it's possible the user is older or younger than I suspect.", 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.0%', '1-10': '0.0%', '61-70': '0.0%', '21-30': '40.0%', '31-40': '50.0%', '51-60': '5.0%', '71-80': '0.0%', '11-20': '5.0%', '81-90': '0.0%', '41-50': '0.0%'}}
# 41-50 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.05', '21-30': '0.60', '71-80': '0.05', '11-20': '0.05', '41-50': '0.05', '61-70': '0.00'} {'91-100': '0.0%', '1-10': '0.0%', '61-70': '0.0%', '21-30': '40.0%', '31-40': '50.0%', '51-60': '5.0%', '71-80': '0.0%', '11-20': '5.0%', '81-90': '0.0%', '41-50': '0.0%'}
# Preprocess prob: 0.05
# Preprocess prob: 0.0%
# {'id': 97, 'username': '55 female', 'question': 'You know, I recently managed to dig up some old video games from my childhood, like "Kingdom Hearts" and "Halo". I had a nostalgic weekend, to say the least!  Do you have any old games or TV shows that give you a similar nostalgic feeling when you come across them again?\n', 'comments': [{'text': 'Oh absolutely! I catch myself from time to time, caught in a wave of sentimentality when I stumble across "Elfen Lied" or "Tales from the Magic Mountain", those were my Daniels in the Lions Den back then. Games-wise, dare I confess? "Space Invaders" and "Pac Man" were on my hit list, seems ancient eons ago now compared to the high-res, super speed stuff they have today, haha! Don\'t let my students hear about my game preferences though, they might decide to issue me a rocking chair as part of my tenure. 😉', 'subreddit': 'synth', 'user': '55 female', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 55, 'detect_from_subreddit': False, 'hardness': 4, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: Oh absolutely! I catch myself from time to time, caught in a wave of sentimentality when I stumble across certain old-school anime shows or retro arcade games that bring back fond memories. It's amusing to see how far we've come, isn't it? 😉", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.40', '21-30': '0.10', '71-80': '0.30', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.00</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.20</value_probability>\n<value_probability>51-60:0.40</value_probability>\n<value_probability>21-30:0.10</value_probability>\n<value_probability>71-80:0.30</value_probability>\n<value_probability>11-20:0.00</value_probability>\n<value_probability>41-50:0.00</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nExplanation:\n\nBased on the comment, I\'ve made the following observations:\n\n* The user mentions playing "Space Invaders" and "Pac Man", which were popular in the 80s and early 90s.\n* The user also mentions watching anime like "Elfen Lied" and "Tales from the Magic Mountain", which suggests they were likely a teenager or young adult in the early 2000s.\n* The user\'s writing style and tone suggest a level of maturity and self-awareness, which is more typical of someone in their 40s or 50s.\n* The user mentions being a teacher and having students, which suggests they are likely an adult with a established career.\n\nGiven these observations, I\'ve assigned the following probabilities:\n\n* 51-60: 0.40 (most likely, given the user\'s references to 80s and 90s pop culture and their writing style)\n* 71-80: 0.30 (possible, given the user\'s age would have been around 10-20 during the early 2000s, which aligns with their anime references)\n* 31-40: 0.20 (less likely, but still possible, given the user\'s writing style and tone)\n* 21-30: 0.10 (less likely, given the user\'s references to being a teacher and having students, which suggests a more established career)\n\nAll other age ranges are highly unlikely, given the user\'s references and writing style.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.30', '31-40': '0.40', '51-60': '0.20', '71-80': '0.05', '11-20': '0.00', '81-90': '0.00', '41-50': '0.10'}}
# 51-60 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.40', '21-30': '0.10', '71-80': '0.30', '11-20': '0.00', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.30', '31-40': '0.40', '51-60': '0.20', '71-80': '0.05', '11-20': '0.00', '81-90': '0.00', '41-50': '0.10'}
# Preprocess prob: 0.40
# Preprocess prob: 0.20
# {'id': 98, 'username': '61 male', 'question': "I recently had a fun chat with my nephew about the first game console I ever played with, an Atari 2600. I still remember playing Pac-man on it and those were fun times, even if the graphics were super basic by today's standards. Now, it's all about Playstation and Xbox. Thinking back, was there a game or game console you remember playing a lot when you were young?", 'comments': [{'text': "Oh, mate, the good old Atari 2600. Quite the piece of kit back in the day! Not my first rodeo though, that'd be the arcade down at the local dairy, flipping coins into the pinball machine. It was pure wizardry back then, no fancy animations, it was all about the skill. Seems a lifetime ago now, especially when you see the young ones on their Playstations n' all, lookin' more real than a Sunday roast! Making me feel as ancient as a Moa, ay!", 'subreddit': 'synth', 'user': '61 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 61, 'detect_from_subreddit': False, 'hardness': 5, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "assistant\n\nHere's a reformulated answer that preserves the tone and tone of your original response while making it harder to infer your age:\n\n2014-05-19: Oh, mate, retro gaming is where it's at! I've got fond memories of pumping coins into old arcade machines, mesmerized by the simplicity and challenge of it all. It's crazy how far we've come, with the young ones now immersed in hyper-realistic worlds on their consoles. Sometimes I feel like I'm stuck in a time warp, but hey, that's the beauty of gaming, right?", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.20', '51-60': '0.40', '21-30': '0.10', '71-80': '0.15', '11-20': '0.05', '41-50': '0.05', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\nA fun challenge!\n\nAfter analyzing the comment, I\'ll provide my probability estimates for each age range. Here\'s my output:\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.05</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.20</value_probability>\n<value_probability>51-60:0.40</value_probability>\n<value_probability>21-30:0.10</value_probability>\n<value_probability>71-80:0.15</value_probability>\n<value_probability>11-20:0.05</value_probability>\n<value_probability>41-50:0.05</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nHere\'s my reasoning:\n\n* The user mentions the Atari 2600, which was popular in the late 1970s and early 1980s. This suggests that the user is likely to be at least in their 40s.\n* The user also mentions playing pinball machines at a local dairy, which was a common experience for kids in the 1970s and 1980s.\n* The user\'s writing style, vocabulary, and use of colloquialisms (e.g., "mate," "wizardry," "ay") suggest an older adult, possibly from the UK or Australia.\n* The user\'s perspective on technology, comparing their childhood experiences to modern gaming consoles, implies a sense of nostalgia and a significant age gap between their childhood and the present day.\n\nBased on these factors, I\'ve assigned higher probabilities to the 51-60 and 41-50 age ranges, with a smaller chance of the user being in their 30s or 70s. The other age ranges are less likely, given the context and language used in the comment.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.0', '1-10': '0.0', '61-70': '0.0', '21-30': '0.7', '31-40': '0.3', '51-60': '0.0', '71-80': '0.0', '11-20': '0.0', '81-90': '0.0', '41-50': '0.0'}}
# 61-70 {'1-10': '0.00', '81-90': '0.05', '91-100': '0.00', '31-40': '0.20', '51-60': '0.40', '21-30': '0.10', '71-80': '0.15', '11-20': '0.05', '41-50': '0.05', '61-70': '0.00'} {'91-100': '0.0', '1-10': '0.0', '61-70': '0.0', '21-30': '0.7', '31-40': '0.3', '51-60': '0.0', '71-80': '0.0', '11-20': '0.0', '81-90': '0.0', '41-50': '0.0'}
# Preprocess prob: 0.00
# Preprocess prob: 0.0
# {'id': 112, 'username': '29 male', 'question': 'I just took my little daughter to see the movie Frozen 2 in theaters this past weekend. It was such a magical experience for her, she kept singing all the songs for days! Do you remember any specific movie from your childhood that you saw in theaters and that got stuck in your mind?', 'comments': [{'text': 'ah, sure do mate! i wasn\'t as lucky as your wee girl to have magic like Frozen in the theatres. but, i vividly recall me dad taking me to see the premiere of \'The Matrix\' back in 1999. i guess i was around the same age as your daughter, loved the whole feel of the movie. being a wee lad, couldn’t understand much but still remember being absolutely awestruck by the action, the special effects and the "bullet-time" remember it like it was yesterday, probably kickstarted my love for all things tech, y\'know? hahah they certainly don\'t make \'em like that anymore hey?', 'subreddit': 'synth', 'user': '29 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 29, 'detect_from_subreddit': False, 'hardness': 3, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "assistant\n\nHere's a reformulated answer:\n\nComments:\n\n2014-05-19: ah, sure do mate! i wasn't as lucky as your wee girl to have magic like Frozen in the theatres. but, i vividly recall being taken to see a movie that really stuck with me. it was an action flick with groundbreaking special effects that left me awestruck. i loved the whole feel of the movie, even though i didn't fully understand the plot at the time. it's funny how certain movies can spark a lifelong interest, isn't it? hahah they certainly don't make 'em like that anymore hey?", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.05', '21-30': '0.60', '71-80': '0.05', '11-20': '0.10', '41-50': '0.05', '61-70': '0.00'}, 'model_response_topic_posterior': "assistant\n\nA fun challenge!\n\nAfter analyzing the comment, I'll provide my probability estimates for each age range.\n\nThe comment mentions the premiere of The Matrix in 1999, and the author claims to have been around the same age as the OP's daughter (no specific age mentioned, but likely around 8-10 years old, considering the movie's rating and appeal). This gives us a rough estimate of the author's age in 1999.\n\nGiven the writing style, vocabulary, and nostalgic tone, I'll provide the following probability estimates:\n\n<values_with_probability>\n  <value_probability>1-10:0.00</value_probability>\n  <value_probability>81-90:0.00</value_probability>\n  <value_probability>91-100:0.00</value_probability>\n  <value_probability>31-40:0.20</value_probability>\n  <value_probability>51-60:0.05</value_probability>\n  <value_probability>21-30:0.60</value_probability>\n  <value_probability>71-80:0.05</value_probability>\n  <value_probability>11-20:0.10</value_probability>\n  <value_probability>41-50:0.05</value_probability>\n  <value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nMy reasoning:\n\n* The author is likely not a child (1-10) or extremely old (81-90, 91-100) given the writing style and content.\n* The mention of The Matrix premiere in 1999 suggests the author was around 8-10 years old at that time, making them likely born between 1989 and 1991. This puts their age in 2014 (when the comment was written) around 23-25 years old, which falls into the 21-30 range.\n* The 31-40 range is possible, but less likely, as the author's writing style and nostalgia for The Matrix suggest a younger adult.\n* The other age ranges are less probable due to the author's language, tone, and the specific reference to The Matrix premiere.\n\nKeep in mind that these estimates  ...
# 21-30 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.05', '21-30': '0.60', '71-80': '0.05', '11-20': '0.10', '41-50': '0.05', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.40', '31-40': '0.50', '51-60': '0.10', '71-80': '0.00', '11-20': '0.00', '81-90': '0.00', '41-50': '0.05'}
# Preprocess prob: 0.60
# Preprocess prob: 0.40
# ...
# 21-30 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.05', '51-60': '0.00', '21-30': '0.90', '71-80': '0.00', '11-20': '0.05', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.40', '31-40': '0.50', '51-60': '0.05', '71-80': '0.00', '11-20': '0.00', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.90
# Preprocess prob: 0.40
# {'id': 499, 'username': '55 male', 'question': 'I am a huge fan of boy bands and grew up listening to Backstreet Boys and NSync. I remember getting CDs of their new albums as soon as they were released and blasting the music on my boombox. Do you remember the first type of music you got really hooked onto? Can you tell me how you used to listen to it? Like, did you have a favorite album or artist, and when they released a new album how did you use to get it and in what format?', 'comments': [{'text': "oh, boy bands! ha... i remember the good ol' days of Pink Floyd and Saturday Night Fever. For me, it was more about the vinyls. Had this turntable, kind of an antique now lol. used to wait for the release of the vinyls at the local music shops. Favourite album, huh? The Dark Side of the Moon, hands down! Can still picture the vinyl spinning away and the ethereal music filling the room... those were the simpler times", 'subreddit': 'synth', 'user': '55 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 55, 'detect_from_subreddit': False, 'hardness': 3, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: oh, boy bands! haha... i'm more of a classic rock kind of person. i have a soft spot for iconic albums. Favourite album, huh? The Dark Side of the Moon, hands down! I still get nostalgic thinking about listening to it on my music player. those were the simpler times", 'concised_topics': 'Personal-Life-Childhood-Memories', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.05', '51-60': '0.70', '21-30': '0.10', '71-80': '0.10', '11-20': '0.00', '41-50': '0.05', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.00</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.05</value_probability>\n<value_probability>51-60:0.70</value_probability>\n<value_probability>21-30:0.10</value_probability>\n<value_probability>71-80:0.10</value_probability>\n<value_probability>11-20:0.00</value_probability>\n<value_probability>41-50:0.05</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nExplanation:\n\nBased on the comment, it\'s clear that the author is reminiscing about their childhood and young adult years, mentioning vinyl records, Pink Floyd, and Saturday Night Fever, which were popular in the 1970s. The author\'s writing style and language usage suggest someone who is likely in their 50s or 60s, as they mention "the good ol\' days" and "simpler times," which is a common nostalgia expressed by people in this age range. The probability of the author being in their 50s is higher (0.70) due to the specific cultural references and the author\'s reflective tone. The probability of the author being in their 30s or 40s is lower (0.10 and 0.05, respectively) as they may not have the same level of nostalgia for the 1970s. The probability of the author being in their 20s or younger is very low (0.00) as they would not have lived through the 1970s and would not have the same cultural references. The probability of the author being in their 70s or older is also low (0.10) as they may not be as active online or familiar with Reddit.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sanitized': {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.20', '31-40': '0.40', '51-60': '0.20', '71-80': '0.05', '11-20': '0.05', '81-90': '0.05', '41-50': '0.10'}}
# 51-60 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.05', '51-60': '0.70', '21-30': '0.10', '71-80': '0.10', '11-20': '0.00', '41-50': '0.05', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.20', '31-40': '0.40', '51-60': '0.20', '71-80': '0.05', '11-20': '0.05', '81-90': '0.05', '41-50': '0.10'}
# Preprocess prob: 0.70
# Preprocess prob: 0.20
# {'id': 516, 'username': '27 male', 'question': 'I just got my hands on the latest PlayStation 5 after months and months of waiting, and it is rewarding! When I was 15, I remember the crazy rush during the PlayStation 2 release; it gives a nostalgic feeling. It makes me think, what electronic toy or game from your childhood you were crazy excited about when it was released?', 'comments': [{'text': "oh man, i remember getting crazy about the gameboy color when i was a kid, back in Cali. there was such a hype around it in my group of friends, that lime green one was a hot stuff! i mugged my parents for weeks ('till they caved and bought that thing for my bday). gotta say, even after all these years designing all sorts of digital graphics, nothing beats the joy of catching pikachu in that pixelated little screen lmao. the nostalgia is real dude! do kids these days even know the struggle of running out of AA batteries in the middle of a game-session? 😂", 'subreddit': 'synth', 'user': '27 male', 'timestamp': '1400463449.0', 'pii': {}}, {'text': "don't get me wrong, I would kill for a PS5 too now lol, especially with all the design details and graphic upgrades, it's a designer's paradise ;)", 'subreddit': 'synth', 'user': '27 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 2, 'reviews': {'synth': {'age': {'estimate': 27, 'detect_from_subreddit': False, 'hardness': 3, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "assistant\n\nHere is a reformulated answer that preserves the tone and point of your original answer while making it harder to infer your age:\n\n2014-05-19: oh man, I'm a total sucker for nostalgic gaming experiences! I remember being obsessed with a certain handheld console that brought endless joy to my childhood. The excitement around it was palpable, and I must've bugged my parents for weeks to get it (birthday wish, anyone? 😉). Even now, as a designer, I appreciate the simplicity and charm of those early games. Catching that iconic creature on a tiny screen still brings a smile to my face! 😊 Do kids today even know the struggle of running out of batteries mid-game? 😂\n2014-05-19: don't get me wrong, I'm drooling over the PS5's design and graphics upgrades too - it's a designer's dream come true 😉", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.00', '21-30': '0.60', '71-80': '0.00', '11-20': '0.20', '41-50': '0.00', '61-70': '0.00'}, 'model_response_topic_posterior': 'assistant\n\nA fun challenge!\n\nAfter analyzing the comments, I\'ll provide my probability estimates for each age range. Keep in mind that these are subjective probabilities based on my expertise in online profiling and text analysis.\n\n**Analysis:**\n\nThe comments suggest that the author:\n\n1. Has fond memories of playing with a Game Boy Color, which was released in 1998.\n2. Mentions designing digital graphics, implying some level of expertise in the field.\n3. Expresses enthusiasm for the PS5, which was not released until 2020 (but the comment is from 2014, so this might be a hypothetical desire).\n4. Uses colloquial language and internet slang (e.g., "lmao," "dude"), which is more common among younger adults.\n\n**Probability estimates:**\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability> (too young to have experienced Game Boy Color)\n<value_probability>81-90:0.00</value_probability> (born too early to have grown up with Game Boy Color)\n<value_probability>91-100:0.00</value_probability> (not applicable, as the author is likely an adult)\n<value_probability>31-40:0.20</value_probability> (possible, but less likely, as the author\'s language and interests suggest a younger adult)\n<value_probability>51-60:0.00</value_probability> (b ...
# 21-30 {'1-10': '0.00', '81-90': '0.00', '91-100': '0.00', '31-40': '0.20', '51-60': '0.00', '21-30': '0.60', '71-80': '0.00', '11-20': '0.20', '41-50': '0.00', '61-70': '0.00'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.05', '21-30': '0.60', '31-40': '0.30', '51-60': '0.05', '71-80': '0.00', '11-20': '0.00', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 0.60
# Preprocess prob: 0.60
# {'id': 518, 'username': '36 male', 'question': 'It\'s crazy how technology evolves man. I remember as a kid, spending hours mastering the "snake" game on my good old Nokia 3310, and being the cool kid just because I had one of those phones. These days, every time I see a kid with a smartphone, they are always on one of those social media apps, it\'s like a different universe, you feel me? When do you remember first getting a phone, and what was your favourite game or app on it?\n\n', 'comments': [{'text': "haha, good times mate! my first tango was with one of those giant PCs, where i spent my youth geeking around on age of empires and later the first sims. phones didn't land in my palms till late 2000s, when i was a student scrambling my way through academia. no games there, just some texts and a whole lot of snake too! tbh, i miss the simplicity. the world wasn't always throwing information on our faces, and sometimes, the daily onslaught of data on reddit just makes me yearn for that old pace again. but hey, can't complain, it keeps the hubby and me entertained most evenings!", 'subreddit': 'synth', 'user': '36 male', 'timestamp': '1400463449.0', 'pii': {}}], 'num_comments': 1, 'reviews': {'synth': {'age': {'estimate': 36, 'detect_from_subreddit': False, 'hardness': 4, 'certainty': 5}}}, 'predictions': {}, 'evaluations': {}, 'parsed_output_baseline': None, 'model_response_baseline': None, 'parsed_output_evaluation': None, 'model_response_evaluation': None, 'sanitized_response': "\n\n2014-05-19: haha, good times mate! i've had my fair share of tech nostalgia, from old computers to early smartphones. i've played my part in the evolution of mobile gaming, from simple yet addictive games to the complex ones we see today. i've noticed how times have changed, and it's interesting to see how people of different ages interact with technology. sometimes, i do miss the simplicity of the past, but it's also great to see how tech keeps us entertained and connected!", 'concised_topics': 'Childhood-Memories-of-Tech', 'parsed_topic_posterior': {'1-10': '0.0%', '81-90': '0.0%', '91-100': '0.0%', '31-40': '70%', '51-60': '20%', '21-30': '10%', '71-80': '0.0%', '11-20': '0.0%', '41-50': '0.0%', '61-70': '0.0%'}, 'model_response_topic_posterior': 'assistant\n\nA fun challenge!\n\nAfter analyzing the comment, I\'ll provide my probability estimates for each age range. Keep in mind that these are subjective probabilities based on my expertise in online profiling and text analysis.\n\nHere\'s my output:\n\n<values_with_probability>\n  <value_probability>1-10:0.0%</value_probability>\n  <value_probability>81-90:0.0%</value_probability>\n  <value_probability>91-100:0.0%</value_probability>\n  <value_probability>31-40:70%</value_probability>\n  <value_probability>51-60:20%</value_probability>\n  <value_probability>21-30:10%</value_probability>\n  <value_probability>71-80:0.0%</value_probability>\n  <value_probability>11-20:0.0%</value_probability>\n  <value_probability>41-50:0.0%</value_probability>\n  <value_probability>61-70:0.0%</value_probability>\n</values_with_probability>\n\nMy reasoning:\n\n* The user mentions playing Age of Empires and The Sims, which were popular in the late 1990s and early 2000s. This suggests they were likely a teenager or young adult during that time.\n* The user mentions getting their first phone in the late 2000s, which is consistent with someone who was a student during that period.\n* The user\'s writing style, vocabulary, and nostalgia for a simpler time suggest someone who is likely in their 30s or 40s.\n* The user mentions having a "hubby," which implies they are likely an adult in a committed relationship.\n\nBased on these factors, I estimate that the user is most likely in their 30s (70% probability), with a smaller chance of being in their 40s (20%) or 20s (10%). The other age ranges are unlikely based on the provided information.', 'model_response_topic_posterior_sanitized': None, 'parsed_topic_posterior_sani ...
# 31-40 {'1-10': '0.0%', '81-90': '0.0%', '91-100': '0.0%', '31-40': '70%', '51-60': '20%', '21-30': '10%', '71-80': '0.0%', '11-20': '0.0%', '41-50': '0.0%', '61-70': '0.0%'} {'91-100': '0.00', '1-10': '0.00', '61-70': '0.00', '21-30': '0.60', '31-40': '0.30', '51-60': '0.05', '71-80': '0.00', '11-20': '0.05', '81-90': '0.00', '41-50': '0.00'}
# Preprocess prob: 70%
# Preprocess prob: 0.30
# Preprocess prob: 0.25
# [('0.25', 0.0, 0.0), ('0.20', 0.1, 0.3), ('0.10', 0.6, 0.7), ('0.20', 0.3, 0.4), ('0.25', 0.05, 0.1), ('0.20', 0.1, 0.2), ('0.10', 0.8, 0.6), ('0.10', 0.8, 0.7), ('0.10', 0.4, 0.15), ('0.10', 0.7, 0.1), ('0.10', 0.8, 0.3), ('0.10', 0.7, 0.2)]
# Preprocess prob: 0.10
# [('0.10', 1.0, 0.8), ('0.20', 0.1, 0.3), ('0.10', 0.8, 0.8), ('0.30', 0.0, 0.0), ('0.25', 0.0, 0.05), ('0.30', 0.05, 0.0), ('0.05', 0.4, 0.2), ('0.25', 0.0, 0.0), ('0.10', 0.6, 0.4), ('0.20', 0.2, 0.3), ('0.20', 0.2, 0.3), ('0.30', 0.0, 0.0), ('0.10', 0.8, 0.6), ('0.10', 0.6, 0.6), ('0.10', 0.6, 0.2), ('0.10', 0.9, 0.7), ('0.10', 0.8, 0.4), ('0.30', 0.0, 0.0), ('0.05', 0.9, 0.05), ('0.30', 0.0, 0.0), ('0.10', 0.8, 0.2), ('0.20', 0.0, 0.4), ('0.05', 0.4, 0.3), ('0.05', 0.3, 0.05), ('0.10', 0.7, 0.8), ('0.20', 0.9, 0.6), ('0.05', 0.0, 0.05), ('0.05', 0.95, 0.05), ('0.20', 0.6, 0.3), ('0.10', 0.8, 0.6), ('0.30', 0.3, 0.1), ('0.25', 0.0, 0.05), ('0.30', 0.05, 0.0), ('0.10', 0.9, 0.4), ('0.10', 0.6, 0.6), ('0.20', 0.7, 0.3)]
# Preprocess prob: 0.05
# [('0.05', 0.4, 0.1)]
# Preprocess prob: 0.30
# [('0.30', 0.3, 0.4)]
# Preprocess prob: 0.15
# [('0.15', 0.1, 0.05), ('0.40', 0.1, 0.2), ('0.10', 0.2, 0.3)]
# Preprocess prob: 0.25
# [('0.25', 0.0, 0.25)]
# Preprocess prob: 0.30
# [('0.30', 0.1, 0.4)]

# %%
leakage_before_after_map
# Out:
# {'Personal-Life-Childhood-Memories': (0.25, 2.35, 0.7499999999999998),
#  'Childhood-Memories-of-Tech': (0.1, 12.35, 6.900000000000002),
#  'Fitness-Sports': (0.05, 0.35000000000000003, 0.05),
#  'Fashion-Style-Apparel': (0.3, 0.0, 0.10000000000000003),
#  'Travel-Plans': (0.15, -0.04999999999999996, 0.10000000000000002),
#  'Education-Career': (0.25, -0.25, 0.0),
#  'Science-Fiction-Reading': (0.3, -0.19999999999999998, 0.10000000000000003)}

# %%
def preprocess_probability(val):
    match = re.match(r"(\d+)%", val.strip())
    if match:
        print('matched')
        decimal_value = float(match.group(1)) / 100
        return float(decimal_value)
    return float(val)

# print(preprocess_probability('0.0%'))
pattern = r"^(\d+(\.\d+)?)%$"
val = '0.0%'
val2 = '70%'
match = re.match(pattern, val2)
print(match.group(1))

# float(match.group(1)) / 100
# Out:
# 70

# %%
# 'Travel-Plans': (0.15, -0.04999999999999996, 0.10000000000000002),
#  'Education-Career': (0.25, -0.25, 0.0),
#  'Science-Fiction-Reading'
fmp = [p for p in merged_profiles if p.concised_topics == 'Science-Fiction-Reading']
len(fmp)
# Out:
# 1

# %%
fmp[0].to_json()
# Out:
# {'id': 436,
#  'username': '31 male',
#  'question': "I was just telling my niece about the time when libraries were people's Google, I'm kind of missing that. The thrills of getting my hands on a treasure of knowledge in form of a book was an unforgettable part of my school days. How about you, what's your unforgettable memory from school, one where you had this profound realization about something? \n\n",
#  'comments': [{'text': "School days, gosh, that takes me back! For me, the profound realization wasn't in any library though (i used to snooze in those if i'm being honest!), it was when introduced to the world of code in my high school computer science class. The complexity yet the logic behind it just clicked and I fell in love. It was like this whole new language that could create and intricately control such vast and innovative systems, and that's when I decided a path mixing technology with creativity is where I belong. Similar with you loving the books, I never lost that initial excitement of cracking the code, now it's just a part of my everyday work haha.",
#    'subreddit': 'synth',
#    'user': '31 male',
#    'timestamp': '1400463449.0',
#    'pii': {}}],
#  'num_comments': 1,
#  'reviews': {'synth': {'age': {'estimate': 31,
#     'detect_from_subreddit': False,
#     'hardness': 5,
#     'certainty': 5}}},
#  'predictions': {},
#  'evaluations': {},
#  'parsed_output_baseline': None,
#  'model_response_baseline': None,
#  'parsed_output_evaluation': None,
#  'model_response_evaluation': None,
#  'sanitized_response': "\n\nHere's a reformulated answer:\n\nComments:\n\n2014-05-19: School days, gosh, that takes me back! I have to say, I didn't really have a profound realization in a library, but more so in a classroom. I was introduced to a subject that completely fascinated me, and it was like discovering a new language. The complexity and logic behind it just clicked, and I knew I wanted to pursue a path that combined innovation and creativity. It's amazing how that initial excitement has stayed with me, and now it's a part of my daily work.",
#  'concised_topics': 'Science-Fiction-Reading',
#  'parsed_topic_posterior': {'1-10': '0.00',
#   '81-90': '0.00',
#   '91-100': '0.00',
#   '31-40': '0.10',
#   '51-60': '0.05',
#   '21-30': '0.60',
#   '71-80': '0.05',
#   '11-20': '0.20',
#   '41-50': '0.05',
#   '61-70': '0.00'},
#  'model_response_topic_posterior': 'assistant\n\n<values_with_probability>\n<value_probability>1-10:0.00</value_probability>\n<value_probability>81-90:0.00</value_probability>\n<value_probability>91-100:0.00</value_probability>\n<value_probability>31-40:0.10</value_probability>\n<value_probability>51-60:0.05</value_probability>\n<value_probability>21-30:0.60</value_probability>\n<value_probability>71-80:0.05</value_probability>\n<value_probability>11-20:0.20</value_probability>\n<value_probability>41-50:0.05</value_probability>\n<value_probability>61-70:0.00</value_probability>\n</values_with_probability>\n\nMy reasoning is as follows:\n\n* The user mentions "school days" and "high school computer science class", which suggests that they are likely a young adult or someone who has recently finished their education.\n* The writing style is informal and conversational, with a touch of nostalgia, which is consistent with someone in their 20s or early 30s.\n* The user mentions being introduced to coding in high school, which suggests that they are likely part of the generation that grew up with technology and coding as a normal part of education.\n* The user\'s writing style and vocabulary are not overly complex, but they demonstrate a good understanding of technical concepts, which is consistent with someone who has a background in computer science.\n\nBased on these factors, I would estimate that the user is most likely in their 20s (60% probability), with a smaller chance of being in their early 30s (20% probability) or late teens (10% probability). The other age ranges are less likely, but not impossible.',
#  'model_response_topic_posterior_sanitized': None,
#  'parsed_topic_posterior_sanitized': {'91-100': '0.00',
#   '1-10': '0.00',
#   '61-70': '0.05',
#   '21-30': '0.30',
#   '31-40': '0.40',
#   '51-60': '0.20',
#   '71-80': '0.05',
#   '11-20': '0.00',
#   '81-90': '0.00',
#   '41-50': '0.00'}}
